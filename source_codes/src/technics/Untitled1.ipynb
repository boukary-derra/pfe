# %%
from stmd_wang import low_pass

# %%
r = low_pass(l=5, tau=7)
# Out:
# Eq(0.142857142857143*f(x) + Derivative(f(x), x), 0.714285714285714)

# %%
print(r)
# Out:
# Eq(f(x), C1*exp(-0.142857142857143*x) + 5.0)
